# %%
import numpy as np
import pandas as pd
from pymongo import MongoClient
np.set_printoptions(suppress=True)
#consider inf and -inf to be “NA” in computations
pd.options.mode.use_inf_as_na = True

client = MongoClient('localhost', 27017)
db = client['IF29']
collection = db['tweets']

# %%
pipeline = [
    {
        "$group": {
            "_id": "$user.id",  
            "tweets": {
                "$push": {  
                    "timestamp_ms": "$timestamp_ms",
                    "user": {
                        "followers_count": "$user.followers_count",
                        "friends_count":"$user.friends_count",
                        "verified":"$user.verified",
                        "created_at":"$user.created_at",
                        "favourites_count":"$user.favourites_count",
                        "statuses_count":"$user.statuses_count",
                        "listed_count":"$user.listed_count"
                    },
                    "retweet_count":"$retweet_count",
                    "entities": {
                        "urls": "$entities.urls",
                        "hashtags": "$entities.hashtags",
                        "user_mentions":"$entities.user_mentions"
                    },
                    "text":"$text",
                    "reply_count":"$reply_count",
                    "created_date":"$created_date",
                    "created_at":"$created_at"
                }
            }
        }
    }
]

# 执行聚合查询
tweets = collection.aggregate(pipeline)

# %%
tweets = list(tweets)

# %%
tweets
# Out:
# [{'_id': 2620092884,
#   'tweets': [{'timestamp_ms': '1528944492131',
#     'user': {'followers_count': 748,
#      'friends_count': 93,
#      'verified': False,
#      'created_at': 'Sat Jul 12 01:54:43 +0000 2014',
#      'favourites_count': 444,
#      'statuses_count': 34250,
#      'listed_count': 4},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [84, 88], 'text': 'KSA'},
#       {'indices': [89, 98], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 17],
#        'screen_name': 'Almoj_alazra8',
#        'id_str': '379309259',
#        'name': 'قروب الموج الأزرق',
#        'id': 379309259}]},
#     'text': 'RT @Almoj_alazra8: إيكر كاسياس :\nأتوقع فوز السعودية على روسيا في إفتتاح المونديال. \n#KSA\n#WorldCup https://t.co/1XVXP1KJ9m',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:48:12',
#     'created_at': 'Thu Jun 14 02:48:12 +0000 2018'}]},
#  {'_id': 3700160833,
#   'tweets': [{'timestamp_ms': '1528943948565',
#     'user': {'followers_count': 180,
#      'friends_count': 55,
#      'verified': False,
#      'created_at': 'Sun Sep 27 04:57:00 +0000 2015',
#      'favourites_count': 69,
#      'statuses_count': 207,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [9, 18], 'text': 'WorldCup'},
#       {'indices': [19, 33], 'text': 'ComeOnEngland'}],
#      'user_mentions': []},
#     'text': "It's the #WorldCup #ComeOnEngland",
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:39:08',
#     'created_at': 'Thu Jun 14 02:39:08 +0000 2018'}]},
#  {'_id': 241631978,
#   'tweets': [{'timestamp_ms': '1528943943297',
#     'user': {'followers_count': 215,
#      'friends_count': 1004,
#      'verified': False,
#      'created_at': 'Sat Jan 22 19:08:49 +0000 2011',
#      'favourites_count': 2974,
#      'statuses_count': 11355,
#      'listed_count': 18},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [35, 41], 'text': 'conFE'},
#       {'indices': [48, 57], 'text': 'worldCup'},
#       {'indices': [60, 71], 'text': 'ArribaPerú'}],
#      'user_mentions': [{'indices': [3, 15],
#        'screen_name': 'Alditocorzo',
#        'id_str': '946685137',
#        'name': 'Aldo Corzo',
#        'id': 946685137}]},
#     'text': 'RT @Alditocorzo: Un día!!! 😅❤🇵🇪⚽🙏🏻\n#conFE ☝🏻🙄☝🏻\n#worldCup 🏆\n#ArribaPerú 🇵🇪❤ https://t.co/PJqho4U27Y',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:39:03',
#     'created_at': 'Thu Jun 14 02:39:03 +0000 2018'}]},
#  {'_id': 817018115133358083,
#   'tweets': [{'timestamp_ms': '1528944107440',
#     'user': {'followers_count': 211,
#      'friends_count': 763,
#      'verified': False,
#      'created_at': 'Thu Jan 05 14:41:12 +0000 2017',
#      'favourites_count': 53968,
#      'statuses_count': 66645,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [18, 29], 'text': 'อาตี๋ของผม'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': 'tha_sataporn',
#        'id_str': '410519373',
#        'name': 'tha_sataporn',
#        'id': 410519373},
#       {'indices': [94, 107],
#        'screen_name': 'FThanatsarun',
#        'id_str': '970147208002617345',
#        'name': 'Frank_thanatsaran',
#        'id': 970147208002617345},
#       {'indices': [108, 122],
#        'screen_name': 'Drake_Laedeke',
#        'id_str': '869234125986603009',
#        'name': 'Drake Laedeke',
#        'id': 869234125986603009},
#       {'indices': [123, 134],
#        'screen_name': 'phuwintang',
#        'id_str': '40408670',
#        'name': 'phuwintang',
#        'id': 40408670}]},
#     'text': 'RT @tha_sataporn: #อาตี๋ของผม อยู่ยันเช้าเลยครับ ขอบคุณแทนน้องๆนักแสดงหน้าใหม่ทุกคนด้วยนะครับ @FThanatsarun @Drake_Laedeke @phuwintang @Nne…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:41:47',
#     'created_at': 'Thu Jun 14 02:41:47 +0000 2018'}]},
#  {'_id': 817131666,
#   'tweets': [{'timestamp_ms': '1528944465367',
#     'user': {'followers_count': 436,
#      'friends_count': 307,
#      'verified': False,
#      'created_at': 'Tue Sep 11 10:23:02 +0000 2012',
#      'favourites_count': 599,
#      'statuses_count': 10908,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [21, 30], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 13],
#        'screen_name': 'ayshardzn',
#        'id_str': '52719612',
#        'name': 'Aysha Ridzuan',
#        'id': 52719612}]},
#     'text': 'RT @ayshardzn: Happy #WorldCup day!',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:47:45',
#     'created_at': 'Thu Jun 14 02:47:45 +0000 2018'}]},
#  {'_id': 793970815,
#   'tweets': [{'timestamp_ms': '1528943678458',
#     'user': {'followers_count': 352,
#      'friends_count': 99,
#      'verified': False,
#      'created_at': 'Fri Aug 31 14:20:31 +0000 2012',
#      'favourites_count': 2825,
#      'statuses_count': 8382,
#      'listed_count': 7},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [74, 78], 'text': 'M12'},
#       {'indices': [80, 91], 'text': 'Russia2018'}],
#      'user_mentions': []},
#     'text': 'Voy a ver este mundial por Marcelo❤️ y ni se molesten en venir por mí.... #M12  #Russia2018 https://t.co/OdHrYDaDDY',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:34:39',
#     'created_at': 'Thu Jun 14 02:34:38 +0000 2018'}]},
#  {'_id': 2436844823,
#   'tweets': [{'timestamp_ms': '1528942576046',
#     'user': {'followers_count': 669,
#      'friends_count': 2031,
#      'verified': False,
#      'created_at': 'Wed Mar 26 00:38:52 +0000 2014',
#      'favourites_count': 2181,
#      'statuses_count': 2287,
#      'listed_count': 5},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [55, 64], 'text': 'WorldCup'},
#       {'indices': [65, 79], 'text': 'worldcupfever'},
#       {'indices': [80, 91], 'text': 'Russia2018'}],
#      'user_mentions': []},
#     'text': "So who's buzzing for the start of the World Cup then ? #WorldCup #worldcupfever #Russia2018",
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:16:16',
#     'created_at': 'Thu Jun 14 02:16:16 +0000 2018'}]},
#  {'_id': 849410451817496578,
#   'tweets': [{'timestamp_ms': '1528943762011',
#     'user': {'followers_count': 32,
#      'friends_count': 63,
#      'verified': False,
#      'created_at': 'Tue Apr 04 23:56:47 +0000 2017',
#      'favourites_count': 2,
#      'statuses_count': 332,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [124, 133], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 11],
#        'screen_name': 'Okwonga',
#        'id_str': '152601415',
#        'name': 'Musa Okwonga',
#        'id': 152601415}]},
#     'text': 'RT @Okwonga: Ah I meant to say - this isn’t a Soundcloud link, don’t worry! - if you enjoyed this thread, you might like my #WorldCup newsl…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:36:02',
#     'created_at': 'Thu Jun 14 02:36:02 +0000 2018'}]},
#  {'_id': 990060188525912064,
#   'tweets': [{'timestamp_ms': '1528942990315',
#     'user': {'followers_count': 316,
#      'friends_count': 666,
#      'verified': False,
#      'created_at': 'Sat Apr 28 02:48:38 +0000 2018',
#      'favourites_count': 7115,
#      'statuses_count': 1478,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/bleacherreport…',
#        'indices': [29, 52],
#        'expanded_url': 'https://twitter.com/bleacherreport/status/1006991352054337536',
#        'url': 'https://t.co/mkTJIHqhb7'}],
#      'hashtags': [],
#      'user_mentions': []},
#     'text': '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f https://t.co/mkTJIHqhb7',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:23:10',
#     'created_at': 'Thu Jun 14 02:23:10 +0000 2018'}]},
#  {'_id': 1004580933729771521,
#   'tweets': [{'timestamp_ms': '1528943103719',
#     'user': {'followers_count': 3,
#      'friends_count': 1,
#      'verified': False,
#      'created_at': 'Thu Jun 07 04:28:53 +0000 2018',
#      'favourites_count': 0,
#      'statuses_count': 47,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140],
#        'expanded_url': 'https://twitter.com/i/web/status/1007086486158798854',
#        'url': 'https://t.co/8Xplelc0Y5'}],
#      'hashtags': [],
#      'user_mentions': []},
#     'text': 'I’d ❤️love ❤️ to be there when he finally did it he did he win he is the great man of the hour who is to say that y… https://t.co/8Xplelc0Y5',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:25:04',
#     'created_at': 'Thu Jun 14 02:25:03 +0000 2018'}]},
#  {'_id': 983099435449225217,
#   'tweets': [{'timestamp_ms': '1528942906658',
#     'user': {'followers_count': 4,
#      'friends_count': 26,
#      'verified': False,
#      'created_at': 'Sun Apr 08 21:49:05 +0000 2018',
#      'favourites_count': 1126,
#      'statuses_count': 342,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [19, 33], 'text': 'BarçaWorldCup'},
#       {'indices': [118, 127], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 15],
#        'screen_name': 'FCBarcelona',
#        'id_str': '96951800',
#        'name': 'FC Barcelona 🏆🏆',
#        'id': 96951800},
#       {'indices': [90, 106],
#        'screen_name': 'FCFSeleccionCol',
#        'id_str': '1117317140',
#        'name': 'Selección Colombia',
#        'id': 1117317140}]},
#     'text': 'RT @FCBarcelona: 🌍 #BarçaWorldCup\n🇨🇴 Quarter-finals in 2014 - how far will Yerry Mina and @FCFSeleccionCol go in this #WorldCup? https://t.…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:21:46',
#     'created_at': 'Thu Jun 14 02:21:46 +0000 2018'}]},
#  {'_id': 1007083269374930944,
#   'tweets': [{'timestamp_ms': '1528942688285',
#     'user': {'followers_count': 0,
#      'friends_count': 0,
#      'verified': False,
#      'created_at': 'Thu Jun 14 02:12:16 +0000 2018',
#      'favourites_count': 0,
#      'statuses_count': 6,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [23, 34], 'text': 'كأس_العالم'},
#       {'indices': [41, 52], 'text': 'Russia2018'},
#       {'indices': [53, 60], 'text': 'WC2018'},
#       {'indices': [61, 74], 'text': 'WorldCup2018'},
#       {'indices': [75, 91], 'text': 'كأس_العالم_2018'},
#       {'indices': [92, 108], 'text': 'المنتخب_السعودي'}],
#      'user_mentions': [{'indices': [3, 10],
#        'screen_name': 'khah15',
#        'id_str': '957406201',
#        'name': 'خالد الدميخي 48',
#        'id': 957406201}]},
#     'text': 'RT @khah15: جدول بطولة #كأس_العالم 2018\n\n#Russia2018\n#WC2018\n#WorldCup2018\n#كأس_العالم_2018 #المنتخب_السعودي https://t.co/Jw7vN0ocDZ',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:18:08',
#     'created_at': 'Thu Jun 14 02:18:08 +0000 2018'}]},
#  {'_id': 985380559911174145,
#   'tweets': [{'timestamp_ms': '1528943255495',
#     'user': {'followers_count': 970,
#      'friends_count': 4146,
#      'verified': False,
#      'created_at': 'Sun Apr 15 04:53:27 +0000 2018',
#      'favourites_count': 401,
#      'statuses_count': 532,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/RealFanPredict…',
#        'indices': [43, 66],
#        'expanded_url': 'https://twitter.com/RealFanPredict/status/1006294315079905280',
#        'url': 'https://t.co/nNVh2yuzsK'}],
#      'hashtags': [{'indices': [0, 9], 'text': 'WorldCup'},
#       {'indices': [11, 24], 'text': 'WorldCup2018'},
#       {'indices': [30, 41], 'text': 'FanPredict'}],
#      'user_mentions': []},
#     'text': '#WorldCup, #WorldCup2018, and #FanPredict, https://t.co/nNVh2yuzsK',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:27:35',
#     'created_at': 'Thu Jun 14 02:27:35 +0000 2018'}]},
#  {'_id': 4067251273,
#   'tweets': [{'timestamp_ms': '1528943299782',
#     'user': {'followers_count': 20,
#      'friends_count': 167,
#      'verified': False,
#      'created_at': 'Fri Oct 30 09:30:58 +0000 2015',
#      'favourites_count': 5632,
#      'statuses_count': 28692,
#      'listed_count': 3},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 17],
#        'screen_name': 'thestandardth',
#        'id_str': '834243316233351169',
#        'name': 'THE STANDARD',
#        'id': 834243316233351169}]},
#     'text': 'RT @thestandardth: เคลียร์ตัวเองให้พร้อม นัดรวมเพื่อนให้ไว มหกรรมกีฬาที่คนทั้งโลกอดใจรอกันมานานถึง 4 ปีเต็มอย่าง ‘ฟุตบอลโลก 2018’ ที่รัสเซี…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:28:20',
#     'created_at': 'Thu Jun 14 02:28:19 +0000 2018'}]},
#  {'_id': 2571199504,
#   'tweets': [{'timestamp_ms': '1528943332092',
#     'user': {'followers_count': 419,
#      'friends_count': 926,
#      'verified': False,
#      'created_at': 'Thu May 29 22:32:25 +0000 2014',
#      'favourites_count': 1561,
#      'statuses_count': 25219,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/kthopkins/stat…',
#        'indices': [78, 101],
#        'expanded_url': 'https://twitter.com/kthopkins/status/1005736378829869056',
#        'url': 'https://t.co/V9cnTvokjV'}],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 10],
#        'screen_name': 'Lzison',
#        'id_str': '990321347032223744',
#        'name': 'Not Who You Think It Is - Im New Here',
#        'id': 990321347032223744}]},
#     'text': 'RT @Lzison: How can it be clean when you’re walking through it you dusty sket https://t.co/V9cnTvokjV',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:28:52',
#     'created_at': 'Thu Jun 14 02:28:52 +0000 2018'}]},
#  {'_id': 2990434404,
#   'tweets': [{'timestamp_ms': '1528942583067',
#     'user': {'followers_count': 168,
#      'friends_count': 206,
#      'verified': False,
#      'created_at': 'Tue Jan 20 00:51:31 +0000 2015',
#      'favourites_count': 5994,
#      'statuses_count': 2051,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [21, 30], 'text': 'WorldCup'},
#       {'indices': [59, 70], 'text': 'United2026'}],
#      'user_mentions': [{'indices': [3, 17],
#        'screen_name': 'HoustonDynamo',
#        'id_str': '14235279',
#        'name': '#VoteDynamo',
#        'id': 14235279}]},
#     'text': 'RT @HoustonDynamo: A #WorldCup in our own backyard! 🇨🇦🇲🇽🇺🇸 #United2026 https://t.co/4WbhVdw4LD',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:16:23',
#     'created_at': 'Thu Jun 14 02:16:23 +0000 2018'}]},
#  {'_id': 945797297673207809,
#   'tweets': [{'timestamp_ms': '1528943794355',
#     'user': {'followers_count': 10,
#      'friends_count': 65,
#      'verified': False,
#      'created_at': 'Tue Dec 26 23:23:42 +0000 2017',
#      'favourites_count': 25,
#      'statuses_count': 500,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [73, 86], 'text': 'WorldCup2018'},
#       {'indices': [122, 137], 'text': 'GoGreenFalcons'}],
#      'user_mentions': [{'indices': [3, 19],
#        'screen_name': 'AlNassrSaudiFCe',
#        'id_str': '908749393',
#        'name': 'AlNassr FC',
#        'id': 908749393},
#       {'indices': [108, 119],
#        'screen_name': 'SaudiNT_EN',
#        'id_str': '993859032040517632',
#        'name': 'Saudi National Team',
#        'id': 993859032040517632}]},
#     'text': 'RT @AlNassrSaudiFCe: Today 6:00 pm,\nThe first step, the opening match in #WorldCup2018 all the best for our @SaudiNT_EN !\n#GoGreenFalcons h…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:36:34',
#     'created_at': 'Thu Jun 14 02:36:34 +0000 2018'}]},
#  {'_id': 3130990552,
#   'tweets': [{'timestamp_ms': '1528943428825',
#     'user': {'followers_count': 44,
#      'friends_count': 133,
#      'verified': False,
#      'created_at': 'Wed Apr 01 02:23:49 +0000 2015',
#      'favourites_count': 4003,
#      'statuses_count': 1477,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140],
#        'expanded_url': 'https://twitter.com/i/web/status/1007087849752203264',
#        'url': 'https://t.co/BKBopuYFep'}],
#      'hashtags': [],
#      'user_mentions': [{'indices': [0, 12],
#        'screen_name': 'NoSoyNanaOK',
#        'id_str': '2581260180',
#        'name': 'No soy NaNá',
#        'id': 2581260180},
#       {'indices': [39, 50],
#        'screen_name': 'fifacom_es',
#        'id_str': '142295586',
#        'name': 'FIFA.com en español',
#        'id': 142295586}]},
#     'text': '@NoSoyNanaOK La “Ley Suarez”| El 01/06 @fifacom_es aprobó el reglamento 2018/19. Regla 12, Faltas y Conducta Incorr… https://t.co/BKBopuYFep',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:30:29',
#     'created_at': 'Thu Jun 14 02:30:28 +0000 2018'}]},
#  {'_id': 967765308189630464,
#   'tweets': [{'timestamp_ms': '1528944271826',
#     'user': {'followers_count': 19,
#      'friends_count': 28,
#      'verified': False,
#      'created_at': 'Sun Feb 25 14:16:44 +0000 2018',
#      'favourites_count': 27,
#      'statuses_count': 1176,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [56, 63], 'text': 'México'}],
#      'user_mentions': [{'indices': [3, 19],
#        'screen_name': 'NUEVAALIANZAHMO',
#        'id_str': '398501360',
#        'name': 'Nueva Alianza Sonora',
#        'id': 398501360}]},
#     'text': 'RT @NUEVAALIANZAHMO: Estamos llamados 🙋\u200d♂a construir un #México 🇲🇽 de legalidad ⚖ equidad🙍🏻\u200d♀🙎🏻\u200d♂ y seguridad👨\u200d✈\nJuntos por la educación📚…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:44:32',
#     'created_at': 'Thu Jun 14 02:44:31 +0000 2018'},
#    {'timestamp_ms': '1528944275199',
#     'user': {'followers_count': 19,
#      'friends_count': 28,
#      'verified': False,
#      'created_at': 'Sun Feb 25 14:16:44 +0000 2018',
#      'favourites_count': 27,
#      'statuses_count': 1177,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [51, 58], 'text': 'México'}],
#      'user_mentions': [{'indices': [3, 14],
#        'screen_name': 'karina_lyz',
#        'id_str': '1135267633',
#        'name': 'KARINA MARTINEZ',
#        'id': 1135267633}]},
#     'text': 'RT @karina_lyz: Estamos llamados 🙋\u200d♂a construir un #México 🇲🇽 de legalidad ⚖ equidad🙍🏻\u200d♀ y seguridad👨\u200d\nJuntos por la educación📚\n#NuevaAlian…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:44:35',
#     'created_at': 'Thu Jun 14 02:44:35 +0000 2018'}]},
#  {'_id': 1050463266,
#   'tweets': [{'timestamp_ms': '1528943536601',
#     'user': {'followers_count': 307,
#      'friends_count': 205,
#      'verified': False,
#      'created_at': 'Mon Dec 31 14:41:56 +0000 2012',
#      'favourites_count': 1692,
#      'statuses_count': 5312,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/FIFAWorldCup/s…',
#        'indices': [60, 83],
#        'expanded_url': 'https://twitter.com/FIFAWorldCup/status/1007017518958080005',
#        'url': 'https://t.co/4La8EtkajY'}],
#      'hashtags': [],
#      'user_mentions': []},
#     'text': 'يا ريت الناس اللى كانت بتتريق على صور المنتخب تخرص خالص بقى https://t.co/4La8EtkajY',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:32:17',
#     'created_at': 'Thu Jun 14 02:32:16 +0000 2018'}]},
#  {'_id': 325106146,
#   'tweets': [{'timestamp_ms': '1528944080078',
#     'user': {'followers_count': 389,
#      'friends_count': 871,
#      'verified': False,
#      'created_at': 'Mon Jun 27 19:02:41 +0000 2011',
#      'favourites_count': 11730,
#      'statuses_count': 27350,
#      'listed_count': 18},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [15, 24], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 13],
#        'screen_name': 'ODDSbible',
#        'id_str': '458638776',
#        'name': 'ODDSbible',
#        'id': 458638776}]},
#     'text': 'RT @ODDSbible: #WorldCup https://t.co/cn5oFRORCB',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:41:20',
#     'created_at': 'Thu Jun 14 02:41:20 +0000 2018'}]},
#  {'_id': 1469904840,
#   'tweets': [{'timestamp_ms': '1528943586859',
#     'user': {'followers_count': 178,
#      'friends_count': 94,
#      'verified': False,
#      'created_at': 'Thu May 30 14:53:04 +0000 2013',
#      'favourites_count': 922,
#      'statuses_count': 43,
#      'listed_count': 2},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [57, 66], 'text': 'WorldCup'},
#       {'indices': [73, 86], 'text': 'WorldCup2018'}],
#      'user_mentions': [{'indices': [19, 32],
#        'screen_name': 'ricky_martin',
#        'id_str': '40255499',
#        'name': 'Ricky Martin',
#        'id': 40255499}]},
#     'text': 'The Cup of Life by @ricky_martin will always be the GOAT #WorldCup song. #WorldCup2018',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:33:07',
#     'created_at': 'Thu Jun 14 02:33:06 +0000 2018'}]},
#  {'_id': 938885441637494784,
#   'tweets': [{'timestamp_ms': '1528944674015',
#     'user': {'followers_count': 8,
#      'friends_count': 22,
#      'verified': False,
#      'created_at': 'Thu Dec 07 21:38:27 +0000 2017',
#      'favourites_count': 82,
#      'statuses_count': 28,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [14, 26], 'text': 'ICanConfirm'},
#       {'indices': [90, 99], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 12],
#        'screen_name': 'DjAludah',
#        'id_str': '251858364',
#        'name': 'Sir. Aludah',
#        'id': 251858364}]},
#     'text': "RT @DjAludah: #ICanConfirm that the guys in charge of Uganda's security cant wait for the #WorldCup to kick off JUST so Ugandans can get di…",
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:51:14',
#     'created_at': 'Thu Jun 14 02:51:14 +0000 2018'}]},
#  {'_id': 1697378904,
#   'tweets': [{'timestamp_ms': '1528944370894',
#     'user': {'followers_count': 938,
#      'friends_count': 323,
#      'verified': False,
#      'created_at': 'Sat Aug 24 20:52:11 +0000 2013',
#      'favourites_count': 42473,
#      'statuses_count': 76113,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [40, 49], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': '10Ronaldinho',
#        'id_str': '29479000',
#        'name': 'Ronaldinho Gaúcho',
#        'id': 29479000}]},
#     'text': 'RT @10Ronaldinho: Vai começar!! 🤙🏾 ⚽ 🇧🇷\n#WorldCup https://t.co/QgiBrHZ2oU',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:46:11',
#     'created_at': 'Thu Jun 14 02:46:10 +0000 2018'}]},
#  {'_id': 225682420,
#   'tweets': [{'timestamp_ms': '1528943764110',
#     'user': {'followers_count': 11807,
#      'friends_count': 11232,
#      'verified': False,
#      'created_at': 'Sun Dec 12 05:27:31 +0000 2010',
#      'favourites_count': 112,
#      'statuses_count': 57706,
#      'listed_count': 19},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [49, 58], 'text': 'WorldCup'}],
#      'user_mentions': []},
#     'text': 'Hoy Arabia  vs Rusia  en el  Luzhniki  stadiun   #WorldCup',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:36:04',
#     'created_at': 'Thu Jun 14 02:36:04 +0000 2018'},
#    {'timestamp_ms': '1528944111432',
#     'user': {'followers_count': 11807,
#      'friends_count': 11232,
#      'verified': False,
#      'created_at': 'Sun Dec 12 05:27:31 +0000 2010',
#      'favourites_count': 112,
#      'statuses_count': 57706,
#      'listed_count': 19},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [46, 55], 'text': 'WorldCup'},
#       {'indices': [59, 66], 'text': 'RUSKSA'},
#       {'indices': [67, 77], 'text': 'روسيا2018'}],
#      'user_mentions': []},
#     'text': 'Hoy Arabia  🇸🇦 vs Rusia  🇷🇺 Estadio Luzhniki  #WorldCup    #RUSKSA #روسيا2018',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:41:51',
#     'created_at': 'Thu Jun 14 02:41:51 +0000 2018'}]},
#  {'_id': 3941564129,
#   'tweets': [{'timestamp_ms': '1528944370612',
#     'user': {'followers_count': 210,
#      'friends_count': 337,
#      'verified': False,
#      'created_at': 'Tue Oct 13 00:00:01 +0000 2015',
#      'favourites_count': 89,
#      'statuses_count': 1093,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [38, 52], 'text': 'مونديال_روسيا'},
#       {'indices': [72, 79], 'text': 'المغرب'},
#       {'indices': [97, 103], 'text': 'فرنسا'},
#       {'indices': [123, 132], 'text': 'استراليا'}],
#      'user_mentions': [{'indices': [3, 15],
#        'screen_name': '90Miinutees',
#        'id_str': '4277830847',
#        'name': 'سبورت 90',
#        'id': 4277830847}]},
#     'text': 'RT @90Miinutees: من هم الاصغر سناً في #مونديال_روسيا \nاشرف حكيمي (منتخب #المغرب) 19\nمبابي (منتخب #فرنسا) 19\n ارزاني (منتخب #استراليا) 19 \nأ…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:46:10',
#     'created_at': 'Thu Jun 14 02:46:10 +0000 2018'}]},
#  {'_id': 192151825,
#   'tweets': [{'timestamp_ms': '1528942617355',
#     'user': {'followers_count': 205,
#      'friends_count': 1054,
#      'verified': False,
#      'created_at': 'Sat Sep 18 09:53:44 +0000 2010',
#      'favourites_count': 61205,
#      'statuses_count': 22021,
#      'listed_count': 4},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 17],
#        'screen_name': 'thestandardth',
#        'id_str': '834243316233351169',
#        'name': 'THE STANDARD',
#        'id': 834243316233351169}]},
#     'text': 'RT @thestandardth: เคลียร์ตัวเองให้พร้อม นัดรวมเพื่อนให้ไว มหกรรมกีฬาที่คนทั้งโลกอดใจรอกันมานานถึง 4 ปีเต็มอย่าง ‘ฟุตบอลโลก 2018’ ที่รัสเซี…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:16:57',
#     'created_at': 'Thu Jun 14 02:16:57 +0000 2018'}]},
#  {'_id': 50341975,
#   'tweets': [{'timestamp_ms': '1528943040753',
#     'user': {'followers_count': 175,
#      'friends_count': 131,
#      'verified': False,
#      'created_at': 'Wed Jun 24 15:50:39 +0000 2009',
#      'favourites_count': 172,
#      'statuses_count': 3821,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [65, 74], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 14],
#        'screen_name': 'martelclem',
#        'id_str': '267163752',
#        'name': 'Clément Martel',
#        'id': 267163752}]},
#     'text': "RT @martelclem: Le VAR est-il dans le fruit ? A l'occasion de la #WorldCup, la FIFA lance l’assistance vidéo à l’arbitrage. Un changement a…",
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:24:00',
#     'created_at': 'Thu Jun 14 02:24:00 +0000 2018'}]},
#  {'_id': 715594293864439808,
#   'tweets': [{'timestamp_ms': '1528943129483',
#     'user': {'followers_count': 327,
#      'friends_count': 223,
#      'verified': False,
#      'created_at': 'Thu Mar 31 17:39:09 +0000 2016',
#      'favourites_count': 1121,
#      'statuses_count': 5693,
#      'listed_count': 3},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [39, 48], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 17],
#        'screen_name': 'InvictosSomos',
#        'id_str': '4488217998',
#        'name': 'Invictos',
#        'id': 4488217998}]},
#     'text': 'RT @InvictosSomos: Contando las horas. #WorldCup https://t.co/6MThDL4hhW',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:25:29',
#     'created_at': 'Thu Jun 14 02:25:29 +0000 2018'}]},
#  {'_id': 2704462722,
#   'tweets': [{'timestamp_ms': '1528943212380',
#     'user': {'followers_count': 312,
#      'friends_count': 321,
#      'verified': False,
#      'created_at': 'Sun Aug 03 16:40:10 +0000 2014',
#      'favourites_count': 13955,
#      'statuses_count': 14396,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [56, 67], 'text': 'UMAMundial'},
#       {'indices': [68, 79], 'text': 'Russia2018'}],
#      'user_mentions': [{'indices': [3, 19],
#        'screen_name': 'metroadelantado',
#        'id_str': '219402785',
#        'name': 'Un Metro Adelantado',
#        'id': 219402785}]},
#     'text': 'RT @metroadelantado: La pregunta que nos hacemos todos. #UMAMundial #Russia2018 https://t.co/iEDB0Fa1QL',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:26:52',
#     'created_at': 'Thu Jun 14 02:26:52 +0000 2018'}]},
#  {'_id': 736590277,
#   'tweets': [{'timestamp_ms': '1528942475194',
#     'user': {'followers_count': 194,
#      'friends_count': 350,
#      'verified': False,
#      'created_at': 'Sat Aug 04 11:39:32 +0000 2012',
#      'favourites_count': 973,
#      'statuses_count': 1230,
#      'listed_count': 10},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [18, 27], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': 'FarleyWrites',
#        'id_str': '70952004',
#        'name': 'Sam Farley',
#        'id': 70952004}]},
#     'text': 'RT @FarleyWrites: #WorldCup advice for anybody visiting.\n\n1) Use Uber from the airport, it’s worth the data hit on your phone. I was quoted…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:14:35',
#     'created_at': 'Thu Jun 14 02:14:35 +0000 2018'}]},
#  {'_id': 264759052,
#   'tweets': [{'timestamp_ms': '1528943262817',
#     'user': {'followers_count': 2268,
#      'friends_count': 1865,
#      'verified': False,
#      'created_at': 'Sat Mar 12 12:13:14 +0000 2011',
#      'favourites_count': 18636,
#      'statuses_count': 10192,
#      'listed_count': 3},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [11, 20], 'text': 'WorldCup'}],
#      'user_mentions': []},
#     'text': 'Cant wait! #WorldCup',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:27:43',
#     'created_at': 'Thu Jun 14 02:27:42 +0000 2018'}]},
#  {'_id': 17936452,
#   'tweets': [{'timestamp_ms': '1528943943958',
#     'user': {'followers_count': 3337,
#      'friends_count': 1678,
#      'verified': False,
#      'created_at': 'Sun Dec 07 05:00:23 +0000 2008',
#      'favourites_count': 8541,
#      'statuses_count': 22555,
#      'listed_count': 305},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [30, 40], 'text': 'TeamMelli'},
#       {'indices': [59, 64], 'text': 'Iran'},
#       {'indices': [72, 81], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 12],
#        'screen_name': 'ntabrizy',
#        'id_str': '81951477',
#        'name': 'Nilo Tabrizy',
#        'id': 81951477}]},
#     'text': 'RT @ntabrizy: Carlos Queiroz, #TeamMelli coach on bringing #Iran to the #WorldCup \n\nQuieroz on sanctions: "Even buying shirts is a challeng…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:39:04',
#     'created_at': 'Thu Jun 14 02:39:03 +0000 2018'}]},
#  {'_id': 633410981,
#   'tweets': [{'timestamp_ms': '1528944396000',
#     'user': {'followers_count': 377,
#      'friends_count': 356,
#      'verified': False,
#      'created_at': 'Thu Jul 12 03:07:02 +0000 2012',
#      'favourites_count': 6711,
#      'statuses_count': 8046,
#      'listed_count': 13},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [15, 24], 'text': 'Worldcup'}],
#      'user_mentions': [{'indices': [25, 32],
#        'screen_name': 'TJA929',
#        'id_str': '63021299',
#        'name': 'Terrence Alleyne',
#        'id': 63021299}]},
#     'text': '2026 is so on. #Worldcup @TJA929 Beyond Ready!',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:46:36',
#     'created_at': 'Thu Jun 14 02:46:36 +0000 2018'}]},
#  {'_id': 3198529590,
#   'tweets': [{'timestamp_ms': '1528944584516',
#     'user': {'followers_count': 548,
#      'friends_count': 509,
#      'verified': False,
#      'created_at': 'Sun May 17 04:45:42 +0000 2015',
#      'favourites_count': 28715,
#      'statuses_count': 23183,
#      'listed_count': 5},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [27, 36], 'text': 'WorldCup'},
#       {'indices': [66, 82], 'text': 'LuzhnikiStadium'},
#       {'indices': [120, 127], 'text': 'RUSKSA'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': 'FIFAWorldCup',
#        'id_str': '138372303',
#        'name': 'FIFA World Cup 🏆',
#        'id': 138372303}]},
#     'text': 'RT @FIFAWorldCup: The 21st #WorldCup kicks off in the magnificent #LuzhnikiStadium only 1⃣6⃣ hours from now...\n\n🇷🇺vs🇸🇦\n\n#RUSKSA https://t.c…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:49:44',
#     'created_at': 'Thu Jun 14 02:49:44 +0000 2018'}]},
#  {'_id': 604883440,
#   'tweets': [{'timestamp_ms': '1528944642786',
#     'user': {'followers_count': 3051,
#      'friends_count': 258,
#      'verified': False,
#      'created_at': 'Sun Jun 10 22:06:06 +0000 2012',
#      'favourites_count': 615,
#      'statuses_count': 809810,
#      'listed_count': 359},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [18, 27], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 11],
#        'screen_name': 'utdxtra',
#        'id_str': '2196205482',
#        'name': 'United Xtra',
#        'id': 2196205482}]},
#     'text': 'RT @utdxtra: It’s #WorldCup day!\n\n🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007fJones\n🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007fRashford\n🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007fLingard\n🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007fYoung\n🇧🇪Fellaini\n🇧🇪Lukaku\n🇧🇷Fred\n🇫🇷Pogba\n🇷🇸Matic\n🇪🇸De…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:50:43',
#     'created_at': 'Thu Jun 14 02:50:42 +0000 2018'}]},
#  {'_id': 313204373,
#   'tweets': [{'timestamp_ms': '1528944350813',
#     'user': {'followers_count': 6371,
#      'friends_count': 2075,
#      'verified': False,
#      'created_at': 'Wed Jun 08 09:11:27 +0000 2011',
#      'favourites_count': 430,
#      'statuses_count': 53417,
#      'listed_count': 18},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [37, 43], 'text': 'روسيا'},
#       {'indices': [44, 48], 'text': 'rus'},
#       {'indices': [80, 88], 'text': 'العنابي'},
#       {'indices': [102, 108], 'text': 'روسيا'}],
#      'user_mentions': [{'indices': [3, 17],
#        'screen_name': 'DRMOHDALSA3DI',
#        'id_str': '322895688',
#        'name': '@DRMOHDALSA3DI',
#        'id': 322895688}]},
#     'text': 'RT @DRMOHDALSA3DI: اخر مواجهة لمنتخب #روسيا #rus ضد منتخب خليجي كانت ضد منتخبنا #العنابي الذي فاز على #روسيا ٢-١ في نوفمبر ٢٠١٦\nودية في است…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:45:51',
#     'created_at': 'Thu Jun 14 02:45:50 +0000 2018'}]},
#  {'_id': 569380696,
#   'tweets': [{'timestamp_ms': '1528944682031',
#     'user': {'followers_count': 61,
#      'friends_count': 615,
#      'verified': False,
#      'created_at': 'Wed May 02 19:57:47 +0000 2012',
#      'favourites_count': 16,
#      'statuses_count': 264,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [42, 55], 'text': 'معاك_يالأخضر'},
#       {'indices': [60, 73], 'text': 'WorldCup2018'},
#       {'indices': [74, 81], 'text': 'RUSKSA'}],
#      'user_mentions': [{'indices': [3, 11],
#        'screen_name': 'SaudiNT',
#        'id_str': '2750005566',
#        'name': 'المنتخب السعودي',
#        'id': 2750005566}]},
#     'text': 'RT @SaudiNT: هز الشباك.. جمهورك وراك! 😍💚\n\n#معاك_يالأخضر 🇸🇦💚\n#WorldCup2018\n#RUSKSA https://t.co/NJR9mR9Gap',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:51:22',
#     'created_at': 'Thu Jun 14 02:51:22 +0000 2018'}]},
#  {'_id': 242964111,
#   'tweets': [{'timestamp_ms': '1528942558316',
#     'user': {'followers_count': 118,
#      'friends_count': 580,
#      'verified': False,
#      'created_at': 'Wed Jan 26 00:31:56 +0000 2011',
#      'favourites_count': 2474,
#      'statuses_count': 687,
#      'listed_count': 4},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [12, 21], 'text': 'WorldCup'}],
#      'user_mentions': []},
#     'text': 'We READY!!! #WorldCup https://t.co/LiIOSm0Dp6',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:15:59',
#     'created_at': 'Thu Jun 14 02:15:58 +0000 2018'}]},
#  {'_id': 420065526,
#   'tweets': [{'timestamp_ms': '1528942568817',
#     'user': {'followers_count': 559,
#      'friends_count': 536,
#      'verified': False,
#      'created_at': 'Thu Nov 24 04:28:17 +0000 2011',
#      'favourites_count': 23777,
#      'statuses_count': 47237,
#      'listed_count': 2},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/sfgiants/statu…',
#        'indices': [69, 92],
#        'expanded_url': 'https://twitter.com/sfgiants/status/1006918660814921728',
#        'url': 'https://t.co/SXcmY9gLxu'}],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 13],
#        'screen_name': 'areezzyyy',
#        'id_str': '260108402',
#        'name': 'Subtle Shade',
#        'id': 260108402}]},
#     'text': 'RT @areezzyyy: I’m going to start driving rn, traffic will be insane https://t.co/SXcmY9gLxu',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:16:09',
#     'created_at': 'Thu Jun 14 02:16:08 +0000 2018'}]},
#  {'_id': 3315163302,
#   'tweets': [{'timestamp_ms': '1528943817018',
#     'user': {'followers_count': 458,
#      'friends_count': 216,
#      'verified': False,
#      'created_at': 'Fri Aug 14 16:18:38 +0000 2015',
#      'favourites_count': 643,
#      'statuses_count': 1444,
#      'listed_count': 11},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [107, 130],
#        'expanded_url': 'https://twitter.com/i/web/status/1007089477951647744',
#        'url': 'https://t.co/PN4JB7JJtV'}],
#      'hashtags': [{'indices': [4, 13], 'text': 'worldcup'}],
#      'user_mentions': [{'indices': [87, 99],
#        'screen_name': 'DFB_Team_EN',
#        'id_str': '2350218440',
#        'name': 'Germany',
#        'id': 2350218440}]},
#     'text': 'The #worldcup starts in just over 12 hours! AHHHHH!!!!!! We can’t wait for Sunday when @DFB_Team_EN plays… https://t.co/PN4JB7JJtV',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:36:57',
#     'created_at': 'Thu Jun 14 02:36:57 +0000 2018'}]},
#  {'_id': 1666804076,
#   'tweets': [{'timestamp_ms': '1528944541044',
#     'user': {'followers_count': 71139,
#      'friends_count': 317,
#      'verified': True,
#      'created_at': 'Tue Aug 13 04:44:51 +0000 2013',
#      'favourites_count': 25,
#      'statuses_count': 112068,
#      'listed_count': 458},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'indianexpress.com/article/fifa/f…',
#        'indices': [74, 97],
#        'expanded_url': 'http://indianexpress.com/article/fifa/fifa-world-cup-2018-substance-over-style-the-key-for-south-koreas-son-heung-min-5216663/',
#        'url': 'https://t.co/acQxSyP9bO'}],
#      'hashtags': [{'indices': [0, 9], 'text': 'WorldCup'}],
#      'user_mentions': []},
#     'text': "#WorldCup \n\nSubstance over style the key for South Korea's Son Heung-min\n\nhttps://t.co/acQxSyP9bO",
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:49:01',
#     'created_at': 'Thu Jun 14 02:49:01 +0000 2018'}]},
#  {'_id': 85649805,
#   'tweets': [{'timestamp_ms': '1528942781908',
#     'user': {'followers_count': 635,
#      'friends_count': 1644,
#      'verified': False,
#      'created_at': 'Tue Oct 27 20:07:28 +0000 2009',
#      'favourites_count': 903,
#      'statuses_count': 7827,
#      'listed_count': 224},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [50, 68], 'text': 'ChinaDailyCartoon'},
#       {'indices': [69, 78], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 17],
#        'screen_name': 'ChinaDailyUSA',
#        'id_str': '87775422',
#        'name': 'China Daily',
#        'id': 87775422}]},
#     'text': 'RT @ChinaDailyUSA: 2018 FIFA World Cup is coming. #ChinaDailyCartoon #WorldCup https://t.co/xAqfl1kxTr',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:19:42',
#     'created_at': 'Thu Jun 14 02:19:41 +0000 2018'}]},
#  {'_id': 741083703930146817,
#   'tweets': [{'timestamp_ms': '1528943010950',
#     'user': {'followers_count': 47,
#      'friends_count': 32,
#      'verified': False,
#      'created_at': 'Fri Jun 10 01:44:58 +0000 2016',
#      'favourites_count': 275,
#      'statuses_count': 8,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 11],
#        'screen_name': 'Arsenal',
#        'id_str': '34613288',
#        'name': 'Arsenal FC',
#        'id': 34613288},
#       {'indices': [38, 51],
#        'screen_name': 'FIFAWorldCup',
#        'id_str': '138372303',
#        'name': 'FIFA World Cup 🏆',
#        'id': 138372303},
#       {'indices': [97, 105],
#        'screen_name': 'ElNennY',
#        'id_str': '1353020900',
#        'name': 'Mohamed ELNeny',
#        'id': 1353020900},
#       {'indices': [110, 126],
#        'screen_name': 'LichtsteinerSte',
#        'id_str': '1611073392',
#        'name': 'Stephan Lichtsteiner',
#        'id': 1611073392}]},
#     'text': 'RT @Arsenal: 1️⃣ more sleep until the @FIFAWorldCup is finally upon us! 😁\n\nGood luck, lads 👊\n\n🇪🇬 @ElNennY \n🇨🇭 @LichtsteinerSte and Granit…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:23:31',
#     'created_at': 'Thu Jun 14 02:23:30 +0000 2018'}]},
#  {'_id': 2193243475,
#   'tweets': [{'timestamp_ms': '1528943808569',
#     'user': {'followers_count': 293,
#      'friends_count': 352,
#      'verified': False,
#      'created_at': 'Thu Nov 14 00:57:45 +0000 2013',
#      'favourites_count': 581,
#      'statuses_count': 16386,
#      'listed_count': 5},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/Socceroos/stat…',
#        'indices': [77, 100],
#        'expanded_url': 'https://twitter.com/Socceroos/status/1006685991799648257',
#        'url': 'https://t.co/M3wNu68DnM'}],
#      'hashtags': [{'indices': [51, 60], 'text': 'fmarinos'},
#       {'indices': [61, 70], 'text': 'WorldCup'},
#       {'indices': [72, 76], 'text': 'Aus'}],
#      'user_mentions': [{'indices': [3, 19],
#        'screen_name': 'takutti_Marinos',
#        'id_str': '4727716500',
#        'name': 'たくっち/next東京戦',
#        'id': 4727716500}]},
#     'text': 'RT @takutti_Marinos: さぁ、W杯だ！\nデゲネクを応援するぞ～\n(￣▽￣)/🇦🇺\n\n#fmarinos #WorldCup \n#Aus https://t.co/M3wNu68DnM',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:36:48',
#     'created_at': 'Thu Jun 14 02:36:48 +0000 2018'}]},
#  {'_id': 827352360955441153,
#   'tweets': [{'timestamp_ms': '1528943262382',
#     'user': {'followers_count': 38,
#      'friends_count': 74,
#      'verified': False,
#      'created_at': 'Fri Feb 03 03:05:49 +0000 2017',
#      'favourites_count': 630,
#      'statuses_count': 1320,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 15],
#        'screen_name': 'CybertronPC',
#        'id_str': '40126414',
#        'name': 'CybertronPC',
#        'id': 40126414}]},
#     'text': 'RT @CybertronPC: ATTENTION! CLX Gaming fam!\n\nIn honor of the World Cup we are doing a system GIVEAWAY!\n\nStarting Friday June 15, 2018 12:00…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:27:42',
#     'created_at': 'Thu Jun 14 02:27:42 +0000 2018'}]},
#  {'_id': 894880202635055105,
#   'tweets': [{'timestamp_ms': '1528943856899',
#     'user': {'followers_count': 31,
#      'friends_count': 66,
#      'verified': False,
#      'created_at': 'Tue Aug 08 11:17:21 +0000 2017',
#      'favourites_count': 661,
#      'statuses_count': 5027,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [78, 88], 'text': 'lithuania'},
#       {'indices': [89, 96], 'text': 'poland'},
#       {'indices': [97, 107], 'text': 'livescore'},
#       {'indices': [108, 117], 'text': 'football'},
#       {'indices': [118, 123], 'text': 'fifa'}],
#      'user_mentions': [{'indices': [3, 17],
#        'screen_name': 'mismatchkings',
#        'id_str': '947674264840364032',
#        'name': 'NHL&MLBsportsbetting',
#        'id': 947674264840364032},
#       {'indices': [19, 33],
#        'screen_name': 'lewy_official',
#        'id_str': '2330223926',
#        'name': 'Robert Lewandowski',
#        'id': 2330223926}]},
#     'text': 'RT @mismatchkings: @lewy_official beautiful freekick goal against Lithuania!\n\n#lithuania #poland #livescore #football #fifa #FifaWorldCup20…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:37:37',
#     'created_at': 'Thu Jun 14 02:37:36 +0000 2018'}]},
#  {'_id': 34723684,
#   'tweets': [{'timestamp_ms': '1528944492928',
#     'user': {'followers_count': 23902,
#      'friends_count': 511,
#      'verified': False,
#      'created_at': 'Thu Apr 23 20:44:55 +0000 2009',
#      'favourites_count': 612,
#      'statuses_count': 29722,
#      'listed_count': 145},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'fantasy.fifa.com/en/leagues?cod…',
#        'indices': [112, 135],
#        'expanded_url': 'https://fantasy.fifa.com/en/leagues?code=7061766C6F672323313839353437232346616E524D58232344575A484A335951',
#        'url': 'https://t.co/4ZzHn7LxVK'}],
#      'hashtags': [{'indices': [63, 74], 'text': 'Russia2018'},
#       {'indices': [86, 93], 'text': 'FanRMX'}],
#      'user_mentions': [{'indices': [3, 10],
#        'screen_name': 'pavlog',
#        'id_str': '34723684',
#        'name': 'Pavlo G',
#        'id': 34723684}]},
#     'text': 'RT @pavlog: Les comparto el link para que le entren al Fantasy #Russia2018 oficial de #FanRMX\n\nParticipen! RT!\n\nhttps://t.co/4ZzHn7LxVK',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:48:13',
#     'created_at': 'Thu Jun 14 02:48:12 +0000 2018'}]},
#  {'_id': 356497651,
#   'tweets': [{'timestamp_ms': '1528943166541',
#     'user': {'followers_count': 590,
#      'friends_count': 527,
#      'verified': False,
#      'created_at': 'Tue Aug 16 23:14:01 +0000 2011',
#      'favourites_count': 2715,
#      'statuses_count': 29366,
#      'listed_count': 2},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [64, 77], 'text': 'WorldCup2018'}],
#      'user_mentions': []},
#     'text': "I'm rock hard already thinking about the Spain vs Portugal game #WorldCup2018",
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:26:06',
#     'created_at': 'Thu Jun 14 02:26:06 +0000 2018'}]},
#  {'_id': 397491232,
#   'tweets': [{'timestamp_ms': '1528943763839',
#     'user': {'followers_count': 6806,
#      'friends_count': 1746,
#      'verified': False,
#      'created_at': 'Mon Oct 24 19:20:19 +0000 2011',
#      'favourites_count': 17988,
#      'statuses_count': 76788,
#      'listed_count': 27},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [30, 37], 'text': 'المغرب'},
#       {'indices': [79, 90], 'text': 'المغرب2026'},
#       {'indices': [119, 127], 'text': 'قطر2022'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': 'FahadBuzwair',
#        'id_str': '225204919',
#        'name': 'فهد بن عبدالعزيز',
#        'id': 225204919}]},
#     'text': 'RT @FahadBuzwair: حظ أوفر للـ #المغرب الشقيق 🇲🇦\n\nقلوبنا كانت معكم، وتمنينا فوز #المغرب2026 لنفرح كما فرح كل العرب بفوز #قطر2022  ، ولكن قدر…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:36:04',
#     'created_at': 'Thu Jun 14 02:36:03 +0000 2018'},
#    {'timestamp_ms': '1528943820471',
#     'user': {'followers_count': 6806,
#      'friends_count': 1746,
#      'verified': False,
#      'created_at': 'Mon Oct 24 19:20:19 +0000 2011',
#      'favourites_count': 17993,
#      'statuses_count': 76793,
#      'listed_count': 27},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 13],
#        'screen_name': 'ALQadiPAL',
#        'id_str': '207901468',
#        'name': 'Palestine',
#        'id': 207901468}]},
#     'text': 'RT @ALQadiPAL: فلسطين اوفت بوعدها ودعمت ملف المغرب.  \nللاسف بعض العرب صوتو لامريكا التي لا تحترمهم\nهذه الصورة  احفظوها للتاريخ .\nلا استوعب…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:37:00',
# ...
#        'id_str': '29479000',
#        'name': 'Ronaldinho Gaúcho',
#        'id': 29479000}]},
#     'text': 'RT @10Ronaldinho: Vai começar!! 🤙🏾 ⚽ 🇧🇷\n#WorldCup https://t.co/QgiBrHZ2oU',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:24:07',
#     'created_at': 'Thu Jun 14 02:24:07 +0000 2018'}]},
#  {'_id': 923644580951666689,
#   'tweets': [{'timestamp_ms': '1528942617604',
#     'user': {'followers_count': 555,
#      'friends_count': 1778,
#      'verified': False,
#      'created_at': 'Thu Oct 26 20:16:43 +0000 2017',
#      'favourites_count': 5929,
#      'statuses_count': 4505,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [30, 39], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 19],
#        'screen_name': 'JasmineLWatkins',
#        'id_str': '303391538',
#        'name': 'Jasmine',
#        'id': 303391538}]},
#     'text': 'RT @JasmineLWatkins: OBJ’s in #WorldCup mode (SN: that ball was in the air for an impressive amount of time) https://t.co/7GTeF4pEwl',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:16:57',
#     'created_at': 'Thu Jun 14 02:16:57 +0000 2018'}]},
#  {'_id': 136678705,
#   'tweets': [{'timestamp_ms': '1528942630271',
#     'user': {'followers_count': 557,
#      'friends_count': 2097,
#      'verified': False,
#      'created_at': 'Sat Apr 24 16:04:04 +0000 2010',
#      'favourites_count': 32791,
#      'statuses_count': 32782,
#      'listed_count': 17},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [37, 46], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 18],
#        'screen_name': 'RichardSHarmon',
#        'id_str': '277185371',
#        'name': 'Richard Harmon',
#        'id': 277185371}]},
#     'text': 'RT @RichardSHarmon: NIPPON BABY!! 🇯🇵 #WorldCup https://t.co/65LK9chmVY',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:17:10',
#     'created_at': 'Thu Jun 14 02:17:10 +0000 2018'}]},
#  {'_id': 150066662,
#   'tweets': [{'timestamp_ms': '1528943925411',
#     'user': {'followers_count': 736,
#      'friends_count': 296,
#      'verified': False,
#      'created_at': 'Mon May 31 00:35:28 +0000 2010',
#      'favourites_count': 4264,
#      'statuses_count': 7215,
#      'listed_count': 4},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [0, 13], 'text': 'WorldCup2018'}],
#      'user_mentions': []},
#     'text': '#WorldCup2018 starts tomorrow &amp; I’m already wearing my spain shirt 🇪🇸',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:38:45',
#     'created_at': 'Thu Jun 14 02:38:45 +0000 2018'}]},
#  {'_id': 505013056,
#   'tweets': [{'timestamp_ms': '1528943499014',
#     'user': {'followers_count': 67,
#      'friends_count': 652,
#      'verified': False,
#      'created_at': 'Sun Feb 26 21:14:37 +0000 2012',
#      'favourites_count': 436,
#      'statuses_count': 419,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/neymarasifre/s…',
#        'indices': [5, 28],
#        'expanded_url': 'https://twitter.com/neymarasifre/status/1006961872833339392',
#        'url': 'https://t.co/ufcyfQ6MDU'}],
#      'hashtags': [],
#      'user_mentions': []},
#     'text': '🇧🇷🇧🇷 https://t.co/ufcyfQ6MDU',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:31:39',
#     'created_at': 'Thu Jun 14 02:31:39 +0000 2018'}]},
#  {'_id': 2390659230,
#   'tweets': [{'timestamp_ms': '1528943955243',
#     'user': {'followers_count': 2158,
#      'friends_count': 1020,
#      'verified': False,
#      'created_at': 'Sat Mar 15 08:31:49 +0000 2014',
#      'favourites_count': 6602,
#      'statuses_count': 4874,
#      'listed_count': 34},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/galsenfootsn/s…',
#        'indices': [34, 57],
#        'expanded_url': 'https://twitter.com/galsenfootsn/status/1006980571732594689',
#        'url': 'https://t.co/l8RIyfGngF'}],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 12],
#        'screen_name': 'Amooniac',
#        'id_str': '471027956',
#        'name': "AME 🇸🇳(Khadim N'diaye FC)",
#        'id': 471027956}]},
#     'text': 'RT @Amooniac: Srap ndey liii rekk https://t.co/l8RIyfGngF',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:39:15',
#     'created_at': 'Thu Jun 14 02:39:15 +0000 2018'}]},
#  {'_id': 3316493276,
#   'tweets': [{'timestamp_ms': '1528942678333',
#     'user': {'followers_count': 289,
#      'friends_count': 191,
#      'verified': False,
#      'created_at': 'Sun Aug 16 04:16:21 +0000 2015',
#      'favourites_count': 5233,
#      'statuses_count': 4566,
#      'listed_count': 5},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 13],
#        'screen_name': 'Papa_Vic7',
#        'id_str': '627765622',
#        'name': 'Victor Galindo',
#        'id': 627765622}]},
#     'text': 'RT @Papa_Vic7: PSA: World Cup begins tomorrow so be ready for people getting fired because they don’t show up for work, missed calls/texts…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:17:58',
#     'created_at': 'Thu Jun 14 02:17:58 +0000 2018'}]},
#  {'_id': 3192079728,
#   'tweets': [{'timestamp_ms': '1528943024322',
#     'user': {'followers_count': 550,
#      'friends_count': 1613,
#      'verified': False,
#      'created_at': 'Mon May 11 13:04:44 +0000 2015',
#      'favourites_count': 3142,
#      'statuses_count': 3545,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [28, 37], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': 'Top_Foottbal',
#        'id_str': '1090243952',
#        'name': 'قمم كرة القدم ™',
#        'id': 1090243952}]},
#     'text': 'RT @Top_Foottbal: الاخضر في #WorldCup\u2060 \u2060 . .\n- المشاركات 4\n- المباريات 13\n- فوز 2\n- تعادل 2\n- خسارة 9\n- سجل 9\n- استقبل 32\n- النقاط 8 من أصل…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:23:44',
#     'created_at': 'Thu Jun 14 02:23:44 +0000 2018'}]},
#  {'_id': 2596925454,
#   'tweets': [{'timestamp_ms': '1528943495426',
#     'user': {'followers_count': 41,
#      'friends_count': 248,
#      'verified': False,
#      'created_at': 'Mon Jun 30 21:35:29 +0000 2014',
#      'favourites_count': 878,
#      'statuses_count': 188,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140],
#        'expanded_url': 'https://twitter.com/i/web/status/1007088129097027584',
#        'url': 'https://t.co/r7FAc5F3M4'}],
#      'hashtags': [{'indices': [4, 13], 'text': 'WorldCup'},
#       {'indices': [42, 46], 'text': 'ENG'},
#       {'indices': [55, 59], 'text': 'LFC'}],
#      'user_mentions': []},
#     'text': 'The #WorldCup is upon us. Best of luck to #ENG and the #LFC players. No injuries please. And maybe that old bastard… https://t.co/r7FAc5F3M4',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:31:35',
#     'created_at': 'Thu Jun 14 02:31:35 +0000 2018'}]},
#  {'_id': 724421139745878016,
#   'tweets': [{'timestamp_ms': '1528942809137',
#     'user': {'followers_count': 2057,
#      'friends_count': 1422,
#      'verified': False,
#      'created_at': 'Mon Apr 25 02:13:53 +0000 2016',
#      'favourites_count': 13884,
#      'statuses_count': 8186,
#      'listed_count': 6},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [40, 49], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': '10Ronaldinho',
#        'id_str': '29479000',
#        'name': 'Ronaldinho Gaúcho',
#        'id': 29479000}]},
#     'text': 'RT @10Ronaldinho: Vai começar!! 🤙🏾 ⚽ 🇧🇷\n#WorldCup https://t.co/QgiBrHZ2oU',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:20:09',
#     'created_at': 'Thu Jun 14 02:20:09 +0000 2018'}]},
#  {'_id': 171742837,
#   'tweets': [{'timestamp_ms': '1528944252600',
#     'user': {'followers_count': 752,
#      'friends_count': 451,
#      'verified': False,
#      'created_at': 'Wed Jul 28 02:04:10 +0000 2010',
#      'favourites_count': 345,
#      'statuses_count': 81347,
#      'listed_count': 7},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [80, 89], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 15],
#        'screen_name': 'SquawkaNews',
#        'id_str': '1944665077',
#        'name': 'Squawka News',
#        'id': 1944665077}]},
#     'text': 'RT @SquawkaNews: OFFICIAL: Fernando Hierro will take charge of Spain during the #WorldCup following the sacking of Julen Lopetegui. https:/…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:44:12',
#     'created_at': 'Thu Jun 14 02:44:12 +0000 2018'}]},
#  {'_id': 923319658236796929,
#   'tweets': [{'timestamp_ms': '1528944587872',
#     'user': {'followers_count': 81,
#      'friends_count': 699,
#      'verified': False,
#      'created_at': 'Wed Oct 25 22:45:35 +0000 2017',
#      'favourites_count': 15449,
#      'statuses_count': 5242,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [27, 36], 'text': 'WorldCup'},
#       {'indices': [66, 82], 'text': 'LuzhnikiStadium'},
#       {'indices': [120, 127], 'text': 'RUSKSA'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': 'FIFAWorldCup',
#        'id_str': '138372303',
#        'name': 'FIFA World Cup 🏆',
#        'id': 138372303}]},
#     'text': 'RT @FIFAWorldCup: The 21st #WorldCup kicks off in the magnificent #LuzhnikiStadium only 1⃣6⃣ hours from now...\n\n🇷🇺vs🇸🇦\n\n#RUSKSA https://t.c…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:49:48',
#     'created_at': 'Thu Jun 14 02:49:47 +0000 2018'}]},
#  {'_id': 375935130,
#   'tweets': [{'timestamp_ms': '1528942591598',
#     'user': {'followers_count': 751,
#      'friends_count': 915,
#      'verified': False,
#      'created_at': 'Mon Sep 19 00:46:46 +0000 2011',
#      'favourites_count': 4370,
#      'statuses_count': 18012,
#      'listed_count': 1},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [42, 51], 'text': 'WorldCup'}],
#      'user_mentions': [{'indices': [3, 16],
#        'screen_name': 'soccerdotcom',
#        'id_str': '15356900',
#        'name': 'SOCCER.COM',
#        'id': 15356900}]},
#     'text': 'RT @soccerdotcom: It’s official. The 2026 #WorldCup will be hosted by USA-Mexico-Canada. https://t.co/XvAN2Y4dEv',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:16:31',
#     'created_at': 'Thu Jun 14 02:16:31 +0000 2018'}]},
#  {'_id': 387846118,
#   'tweets': [{'timestamp_ms': '1528944720010',
#     'user': {'followers_count': 1204,
#      'friends_count': 288,
#      'verified': False,
#      'created_at': 'Sun Oct 09 19:29:20 +0000 2011',
#      'favourites_count': 5286,
#      'statuses_count': 18429,
#      'listed_count': 10},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/FutbolBible/st…',
#        'indices': [73, 96],
#        'expanded_url': 'https://twitter.com/FutbolBible/status/1007028205000282113',
#        'url': 'https://t.co/RiGtpkVvVK'}],
#      'hashtags': [],
#      'user_mentions': [{'indices': [3, 12],
#        'screen_name': 'SCRVines',
#        'id_str': '2555862950',
#        'name': 'Soccer Vines',
#        'id': 2555862950}]},
#     'text': 'RT @SCRVines: USA winning the World Cup this year idc what anyone says.. https://t.co/RiGtpkVvVK',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:52:00',
#     'created_at': 'Thu Jun 14 02:52:00 +0000 2018'}]},
#  {'_id': 2316004721,
#   'tweets': [{'timestamp_ms': '1528944210291',
#     'user': {'followers_count': 94,
#      'friends_count': 440,
#      'verified': False,
#      'created_at': 'Fri Jan 31 12:19:00 +0000 2014',
#      'favourites_count': 2854,
#      'statuses_count': 3242,
#      'listed_count': 0},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [51, 57], 'text': 'روسيا'}],
#      'user_mentions': [{'indices': [3, 19],
#        'screen_name': 'RevolutionSyria',
#        'id_str': '261364499',
#        'name': 'Syrian Revolution Network شبكة الثورة السورية',
#        'id': 261364499}]},
#     'text': 'RT @RevolutionSyria: كأس العالم لكرة القدم 2018 في #روسيا\nكأس يفيض بدماء أطفال سوريا\nيشهد على إجرام روسيا\nونفاق وتخاذل العالم، بل ومشاركته…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:43:30',
#     'created_at': 'Thu Jun 14 02:43:30 +0000 2018'}]},
#  {'_id': 306858373,
#   'tweets': [{'timestamp_ms': '1528943308804',
#     'user': {'followers_count': 1164,
#      'friends_count': 808,
#      'verified': False,
#      'created_at': 'Sat May 28 15:33:22 +0000 2011',
#      'favourites_count': 93,
#      'statuses_count': 2113,
#      'listed_count': 3},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [36, 42], 'text': 'Egypt'},
#       {'indices': [87, 96], 'text': 'WorldCup'},
#       {'indices': [97, 108], 'text': 'Russia2018'},
#       {'indices': [113, 120], 'text': 'Africa'},
#       {'indices': [125, 136], 'text': 'MiddleEast'}],
#      'user_mentions': [{'indices': [3, 15],
#        'screen_name': 'Moude_Angel',
#        'id_str': '2861560210',
#        'name': 'Grandson of Pharaohs M.Albadr🇪🇬',
#        'id': 2861560210}]},
#     'text': 'RT @Moude_Angel: for the first time #Egypt is officially and regionally supporting the #WorldCup #Russia2018 for #Africa,the #MiddleEast an…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:28:29',
#     'created_at': 'Thu Jun 14 02:28:28 +0000 2018'},
#    {'timestamp_ms': '1528943324436',
#     'user': {'followers_count': 1164,
#      'friends_count': 808,
#      'verified': False,
#      'created_at': 'Sat May 28 15:33:22 +0000 2011',
#      'favourites_count': 93,
#      'statuses_count': 2114,
#      'listed_count': 3},
#     'retweet_count': 0,
#     'entities': {'urls': [],
#      'hashtags': [{'indices': [92, 98], 'text': 'Egypt'}],
#      'user_mentions': [{'indices': [3, 15],
#        'screen_name': 'Moude_Angel',
#        'id_str': '2861560210',
#        'name': 'Grandson of Pharaohs M.Albadr🇪🇬',
#        'id': 2861560210}]},
#     'text': 'RT @Moude_Angel: Documenting a great historical moment in front of this great edifice,where #Egypt prides itself in declaring itself the of…',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:28:44',
#     'created_at': 'Thu Jun 14 02:28:44 +0000 2018'}]},
#  {'_id': 80777173,
#   'tweets': [{'timestamp_ms': '1528943402688',
#     'user': {'followers_count': 9511,
#      'friends_count': 6058,
#      'verified': False,
#      'created_at': 'Thu Oct 08 05:47:52 +0000 2009',
#      'favourites_count': 182,
#      'statuses_count': 14560,
#      'listed_count': 25},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'twitter.com/tsogie/status/…',
#        'indices': [56, 79],
#        'expanded_url': 'https://twitter.com/tsogie/status/1007073051421364226',
#        'url': 'https://t.co/kbUdvIgTCW'}],
#      'hashtags': [],
#      'user_mentions': []},
#     'text': 'Зориуд сулхан багтай тааруулдаг байж магадгүй юм тээ :) https://t.co/kbUdvIgTCW',
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:30:03',
#     'created_at': 'Thu Jun 14 02:30:02 +0000 2018'}]},
#  {'_id': 123261230,
#   'tweets': [{'timestamp_ms': '1528944451629',
#     'user': {'followers_count': 454,
#      'friends_count': 438,
#      'verified': False,
#      'created_at': 'Mon Mar 15 14:22:13 +0000 2010',
#      'favourites_count': 1070,
#      'statuses_count': 13753,
#      'listed_count': 17},
#     'retweet_count': 0,
#     'entities': {'urls': [{'display_url': 'untp.beer/s/b350741391',
#        'indices': [57, 80],
#        'expanded_url': 'http://untp.beer/s/b350741391',
#        'url': 'https://t.co/rNJzWupXZV'}],
#      'hashtags': [{'indices': [81, 90], 'text': 'worldcup'}],
#      'user_mentions': [{'indices': [47, 55],
#        'screen_name': 'untappd',
#        'id_str': '147845476',
#        'name': 'Untappd',
#        'id': 147845476}]},
#     'text': "I just earned the 'World Pint (2018)' badge on @untappd! https://t.co/rNJzWupXZV #worldcup",
#     'reply_count': 0,
#     'created_date': '2018-06-14 04:47:31',
#     'created_at': 'Thu Jun 14 02:47:31 +0000 2018'}]},
#  ...]

# %%
import json

with open('output.json', 'w') as f:
    json.dump(tweets, f)
